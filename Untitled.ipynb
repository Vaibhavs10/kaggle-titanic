# %%
import pandas as pd

# %%
df = pd.read_csv('submit.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df['PassengerId'].values).tolist())
# Out:
#   File "<ipython-input-4-20dffccf0bb7>", line 1
#     df['PassengerId'].values.tolist())
#                                      ^
# SyntaxError: invalid syntax

# %%
# Out:
# list
